# %% [markdown]
# # Discourse Analysis

# %% [markdown]
# ## Parse discourse tree with DPLP

# %%
# -*- coding: utf-8 -*-
import scipy
import numpy as np
import sklearn
import nltk
import tkinter

# %% [markdown]
# ### Parsing of [file].brackets

# %%
filename='../data/test_tree.brackets'
def parse(filename):
    struct=list()
    with open(filename,'r') as f:
        for index,l in enumerate(f):
            s=l.split()
            s1=int(s[0][2])
            s2=int(s[1][0])
            nuc=s[2][1:-2] #nuclearity: Nucleus or Satellite
            rel=s[3][1:-2] #relation: 78 relations + 3
            struct.append({0:s1, 1:s2, 'nuc':nuc,'rel':rel})
    return struct

s=parse(filename)
print np.unique([r['rel'] for r in s])
# Out:
# ['elaboration' 'purpose' 'span' 'temporal' 'textualorganization']

# %% [markdown]
# ## Classifier
# ### Abstract class

# %%
class Classifier(object):
    def fit(self,x,y):
        raise NotImplementedError("fit not implemented")
    def predict(self,x):
        raise NotImplementedError("predict not implemented")
    def score(self,x,y):
        return (self.predict(x)==y).mean()

# %% [markdown]
# ### Logit regression

# %%
def sig(x,w):
    return 1./(1+np.exp(x.dot(w)))

def sig_grad(x,w):    
    return x*(sig(x,w)*(1.-sig(x,w)))    
    
class Logit(Classifier):
    def __init__(self):
        pass
    
    def fit(self,x,y,eps):
        w=np.ones((len(x[0]),1))
        l=y-sig(x,w)
        l=np.hstack((l,l))
        for i in range(400):
            print w
            w.T[0]-=eps*(sig_grad(x,w).T.dot(l)).sum(axis=0).T
            
            
        self.w=w
        return w
    
    def predict(self,x):
        return sig(x,self.w)
    
    def score(self,x,y):
        pass
    
datax=np.array([[3,1],[2,2],[0,0]])
datay=np.array([[1,-1,1]]).T
w=np.ones((len(datax[0]),1))
log=Logit()

x=datax
y=datay


log.fit(x,y,0.01)
# Out:
# [[ 1.]
#  [ 1.]]
# [[ 1.00002541]
#  [ 1.00002541]]
# [[ 1.00005083]
#  [ 1.00005083]]
# [[ 1.00007624]
#  [ 1.00007624]]
# [[ 1.00010164]
#  [ 1.00010164]]
# [[ 1.00012705]
#  [ 1.00012705]]
# [[ 1.00015245]
#  [ 1.00015245]]
# [[ 1.00017785]
#  [ 1.00017785]]
# [[ 1.00020325]
#  [ 1.00020325]]
# [[ 1.00022864]
#  [ 1.00022864]]
# [[ 1.00025404]
#  [ 1.00025404]]
# [[ 1.00027943]
#  [ 1.00027943]]
# [[ 1.00030481]
#  [ 1.00030481]]
# [[ 1.0003302]
#  [ 1.0003302]]
# [[ 1.00035558]
#  [ 1.00035558]]
# [[ 1.00038096]
#  [ 1.00038096]]
# [[ 1.00040634]
#  [ 1.00040634]]
# [[ 1.00043171]
#  [ 1.00043171]]
# [[ 1.00045709]
#  [ 1.00045709]]
# [[ 1.00048246]
#  [ 1.00048246]]
# [[ 1.00050782]
#  [ 1.00050782]]
# [[ 1.00053319]
#  [ 1.00053319]]
# [[ 1.00055855]
#  [ 1.00055855]]
# [[ 1.00058391]
#  [ 1.00058391]]
# [[ 1.00060927]
#  [ 1.00060927]]
# [[ 1.00063462]
#  [ 1.00063462]]
# [[ 1.00065998]
#  [ 1.00065998]]
# [[ 1.00068533]
#  [ 1.00068533]]
# [[ 1.00071067]
#  [ 1.00071067]]
# ...

# %% [markdown]
# ### Multi Layer Perceptron

# %%
a = np.array([1,2,3,4])
b = np.array([2,3,4,5])
print (a*b)
# Out:
# [ 2  6 12 20]

# %%
il=0.1*13+15.5*0.3+17*0.6
ml=15.7
co=0.3*16.+0.35*8.25+0.35*13.8
lr=12.28
mo=0.15*16+0.425*11.5+16.25*0.425
ma=16.
print np.mean([il,ml,co,lr,mo,ma])
# Out:
# 14.4735416667

# %% [markdown]
# ## Results

# %%
np.sum([[1.,3.],[2.,1.]],axis=0)
# Out:
# array([ 3.,  4.])

# %% [markdown]
# ## Conclusion

# %%
from nltk.tree import Tree
tree = Tree.fromstring('( NN-textualorganization ( EDU 1 )  ( SN-purpose ( NS-elaboration ( EDU 2 )  ( NS-temporal ( EDU 3 )  ( EDU 4 )  )  )  ( NS-elaboration ( NS-elaboration ( EDU 5 )  ( EDU 6 )  )  ( EDU 7 )  )  )  )')
#tree.draw()
print tree
# Out:
# (NN-textualorganization
#   (EDU 1)
#   (SN-purpose
#     (NS-elaboration (EDU 2) (NS-temporal (EDU 3) (EDU 4)))
#     (NS-elaboration (NS-elaboration (EDU 5) (EDU 6)) (EDU 7))))

# %%
s='(NN-textualorganization\
    (EDU 1)\
  (SN-purpose\
    (NS-elaboration (EDU 2) (NS-temporal (EDU 3) (EDU 4)))\
    (NS-elaboration (NS-elaboration (EDU 5) (EDU 6)) (EDU 7))))'
l=[i if(not i[0].isdigit()) else i[1:] for i in s.split() ]

s=' '.join(l)
print s
t=Tree.fromstring(s)
t
# Out:
# (NN-textualorganization (EDU ) (SN-purpose (NS-elaboration (EDU ) (NS-temporal (EDU ) (EDU ))) (NS-elaboration (NS-elaboration (EDU ) (EDU )) (EDU ))))
# Tree('NN-textualorganization', [Tree('EDU', []), Tree('SN-purpose', [Tree('NS-elaboration', [Tree('EDU', []), Tree('NS-temporal', [Tree('EDU', []), Tree('EDU', [])])]), Tree('NS-elaboration', [Tree('NS-elaboration', [Tree('EDU', []), Tree('EDU', [])]), Tree('EDU', [])])])])

# %%
import re
g=tree.subtrees()
i=0
for s in g:
    i+=1
def clean_tree(tree):
    """Returns a tree without any digits"""
    strtree=str(tree)
    match=re.findall(r'[^0-9]+',str(strtree))
    strtree=''.join(match)
    return Tree.fromstring(strtree)


t=clean_tree(tree)
#t=clean_tree(tree)
#l=[str(s) for s in t.subtrees()]
l_clean=[str(s).replace('\n','') for s in t.subtrees()]

def dist(tree1,tree2):
    t1=clean_tree(tree1)
    t2=clean_tree(tree2)
    l1=[str(s1).replace('\n','') for s1 in t1.subtrees()]
    common_subtrees=0
    for s1 in l1:
        if(s1 in str(t2)):
            common_subtrees+=1
    return common_subtrees

def kernel(tree1,tree2):
    t1=clean_tree(tree1)
    t2=clean_tree(tree2)
    kernel_aux(t1,t2,0)

def kernel_aux(t1,t2,n):
    if()
    for node in t1:
        if(node.productions())
        
        
t1.productions()
kernel(t1,t2)
# Out:
# [NN-textualorganization -> EDU SN-purpose, EDU -> , SN-purpose -> NS-elaboration NS-elaboration, NS-elaboration -> EDU NS-temporal, EDU -> , NS-temporal -> EDU EDU, EDU -> , EDU -> , NS-elaboration -> NS-elaboration EDU, NS-elaboration -> EDU EDU, EDU -> , EDU -> , EDU -> ]

# %%
t1=Tree.fromstring('( NN-textualorganization ( EDU 1 )  ( SN-purpose ( NS-elaboration ( EDU 2 )  ( NS-temporal ( EDU 3 )  ( EDU 4 )  )  )  ( NS-elaboration ( NS-elaboration ( EDU 5 )  ( EDU 6 )  )  ( EDU 7 )  )  )  )')
t2=tree = Tree.fromstring('( NN-textualorganization ( EDU 1 )  ( SN-purpose ( NS-elaboration ( EDU 2 )  ( NS-temporal ( EDU 3 )  ( EDU 4 )  )  )  ( NS-elaboration     ( EDU 7 )  )  )  )')
print dist(t1,t2)
t1
# Out:
# 9
# Tree('NN-textualorganization', [Tree('EDU', ['1']), Tree('SN-purpose', [Tree('NS-elaboration', [Tree('EDU', ['2']), Tree('NS-temporal', [Tree('EDU', ['3']), Tree('EDU', ['4'])])]), Tree('NS-elaboration', [Tree('NS-elaboration', [Tree('EDU', ['5']), Tree('EDU', ['6'])]), Tree('EDU', ['7'])])])])

# %%
t2
# Out:
# Tree('NN-textualorganization', [Tree('EDU', ['1']), Tree('SN-purpose', [Tree('NS-elaboration', [Tree('EDU', ['2']), Tree('NS-temporal', [Tree('EDU', ['3']), Tree('EDU', ['4'])])]), Tree('NS-elaboration', [Tree('EDU', ['7'])])])])

# %%
t1.productions()
# Out:
# [NN-textualorganization -> EDU SN-purpose,
#  EDU -> '1',
#  SN-purpose -> NS-elaboration NS-elaboration,
#  NS-elaboration -> EDU NS-temporal,
#  EDU -> '2',
#  NS-temporal -> EDU EDU,
#  EDU -> '3',
#  EDU -> '4',
#  NS-elaboration -> NS-elaboration EDU,
#  NS-elaboration -> EDU EDU,
#  EDU -> '5',
#  EDU -> '6',
#  EDU -> '7']
